# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'SRC')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),"..")))

# %%
# %pwd
# Out:
# 'd:\\Movie recommendation system\\Notebooks'

# %%
os.chdir("../")
# %pwd
# Out:
# 'd:\\Movie recommendation system'

# %%
path = r"./datasets/archive (2)"
file_path = os.path.join(path,"movies_metadata.csv")
print("file_path",file_path)
print("Exists",os.path.exists(file_path))
# Out:
# file_path ./datasets/archive (2)\movies_metadata.csv
# Exists True

# %%
from SRC.data_loader import merge_datasets

API_KEY = "b7e4526c"
#BASE_PATH = "D:\Movie recommendation system\datasets\archive (2)\movies_metadata.csv"

merged_df = merge_datasets(file_path, API_KEY)
merged_df.head()
# Out:
# d:\Movie recommendation system\SRC\data_loader.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# 100%|██████████| 1000/1000 [19:29<00:00,  1.17s/it]
# Final merged dataset ready
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview release_date     id  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30    862
# 1  When siblings Judy and Peter discover an encha...   1995-12-15   8844
# 2  A family wedding reignites the ancient feud be...   1995-12-22  15602
# 3  Cheated on, mistreated and stepped on, the wom...   1995-12-22  31357
# 4  Just when George Banks has recovered from his ...   1995-02-10  11862
#
#   imdb_rating  runtime         director  \
# ...

# %%
merged_df.tail(25)
# Out:
#                                   title  \
# 42252                    In a Heartbeat
# 42253            Blood, Sweat and Tears
# 42254                      Jungle Woman
# 42255                 To Be Fat Like Me
# 42256                       Cadet Kelly
# 42257   The Scheming Gambler's Paradise
# 42258      The Man with the Rubber Head
# 42259          The Living Playing Cards
# 42260             The Hilarious Posters
# 42261               The Devilish Tenant
# 42262           The Untameable Whiskers
# 42263  The Imperceptable Transmutations
# 42264  Pooh's Heffalump Halloween Movie
# 42265                  The One-Man Band
# 42266  The Fat and Lean Wrestling Match
# 42267                       Deep Hearts
# 42268         St. Michael Had a Rooster
# 42269                  House of Horrors
# 42270         Shadow of the Blair Witch
# 42271               The Burkittsville 7
# 42272                   Caged Heat 3000
# 42273                            Subdue
# ...

# %%
merged_df.to_csv("datasets/merged_movies.csv", index=False)
print("Merged datasets saved to datasets/merged_movies.csv")
# Out:
# Merged datasets saved to datasets/merged_movies.csv

# %%
# %pwd
# Out:
# 'd:\\Movie recommendation system'

# %%
from SRC.data_verification import verify_and_cleaned
path = "datasets/merged_movies.csv"
save_path = "datasets/cleaned_df.csv"

cleaned_df = verify_and_cleaned(path, save_path)
cleaned_df.head()
# Out:
# Before cleaning (42277, 9)
# After cleaning (42277, 9)
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview release_date     id  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30    862
# 1  When siblings Judy and Peter discover an encha...   1995-12-15   8844
# 2  A family wedding reignites the ancient feud be...   1995-12-22  15602
# 3  Cheated on, mistreated and stepped on, the wom...   1995-12-22  31357
# 4  Just when George Banks has recovered from his ...   1995-02-10  11862
#
#    imdb_rating  runtime         director  \
# 0          8.3   81 min    John Lasseter
# 1          7.1  104 min     Joe Johnston
# 2          6.7  101 min    Howard Deutch
# 3          6.0  124 min  Forest Whitaker
# 4          6.1  106 min    Charles Shyer
#
# ...
