# %%
import os

# %pwd
# Out:
# 'd:\\Movie recommendation system\\Notebooks'

# %%
os.chdir("../")
# %pwd
# Out:
# 'd:\\Movie recommendation system'

# %%
import pandas as pd 

df = pd.read_csv("datasets/movie_with_user_rating.csv")

df.head(5)
# Out:
# C:\Users\anuj verma\AppData\Local\Temp\ipykernel_17724\770992405.py:3: DtypeWarning: Columns (3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("datasets/movie_with_user_rating.csv")
#     user_id  movie_id      title imdb_rating  \
# 0  user_126      1001  Inception         8.8
# 1  user_166      1001  Inception         8.8
# 2  user_122      1001  Inception         8.8
# 3   user_33      1001  Inception         8.8
# 4  user_141      1001  Inception         8.8
#
#                                               actors      where_to_watch  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Amazon Prime Video
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Amazon Prime Video
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Amazon Prime Video
# 3  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Amazon Prime Video
# 4  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Amazon Prime Video
#
# ...

# %%
print(df.shape)
# Out:
# (16786850, 8)

# %%
df.groupby("user_id")["title"].count()
# Out:
# user_id
# user_1      56146
# user_10     56024
# user_100    55683
# user_101    56103
# user_102    55745
#             ...
# user_95     55853
# user_96     55923
# user_97     55812
# user_98     55440
# user_99     55772
# Name: title, Length: 300, dtype: int64

# %%
df2 = pd.read_csv("datasets/enriched_movies_platform.csv")

df2.head(10)
# Out:
# C:\Users\anuj verma\AppData\Local\Temp\ipykernel_17724\1979438066.py:1: DtypeWarning: Columns (3,7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("datasets/enriched_movies_platform.csv")
#                      title                                           overview  \
# 0                Inception  Cobb, a skilled thief who commits corporate es...
# 1             Interstellar  The adventures of a group of explorers who mak...
# 2          The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3                   Avatar  In the 22nd century, a paraplegic Marine is di...
# 4             The Avengers  When an unexpected enemy emerges and threatens...
# 5                 Deadpool  The origin story of former Special Forces oper...
# 6   Avengers: Infinity War  As the Avengers and their allies have continue...
# 7               Fight Club  A ticking-time-bomb insomniac and a slippery s...
# ...

# %%
df2.isnull().sum()
# Out:
# title                   5
# overview           290538
# language             7270
# release_year       243359
# tmdb_rating          7269
# tmdb_id              7269
# imdb_id            643292
# director          1271257
# actors            1271251
# imdb_rating       1271254
# genre             1278521
# poster            1278523
# where_to_watch    1278914
# dtype: int64

# %%
df2.groupby("language")["title"].count()
# Out:
# language
# English                                 379
# English, Albanian, Spanish, Polish        1
# English, Algonquin                        1
# English, American Sign                    9
# English, American Sign , Estonian         1
#                                       ...
# yi                                       89
# yo                                       45
# za                                        2
# zh                                    41825
# zu                                      120
# Name: title, Length: 464, dtype: int64
